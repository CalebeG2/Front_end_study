# %% [markdown]
# <a href="https://colab.research.google.com/github/CalebeG2/Front_end_study/blob/main/O_In%C3%ADcio_da_Aurora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
# # Ignition Zero: O Início da Aurora
# ### Relatório operacional de pré-decolagem
# ![um-foguete-que-tem-a-palavra-espaco-nele_1340-44989.avif](data:image/avif;base64,...)
#
#
# ---

# %% [markdown]
# ##Telemetria inicial
